# %% [markdown]
# # Sleep Health & Lifestyle
#
# The following dataset we are going to explore is a collection on sleep health indicated by its duration and quality as well as lifestyle factors such as stress level and daily steps as well as cardiocascular aspects such as BMI category or Blood Pressure. The data set includes the following variables:
#
# 1. **Demographics** 🧑‍🦰
#
#     | |  |
#     |--------------|-------------|
#     | **Person ID**  | Unique identifier for each individual |
#     | **Gender**     | 🚻 (Male/Female) |
#     | **Age**        | 📅 (Years) |
#     | **Occupation** | 💼 (e.g., Software Engineer, Doctor, Teacher) |
#
# <br>
#
# 2. **Lifestyle** 🏃‍♀️
#
#     | |  |
#     |----------------------------|-------------|
#     | **Physical Activity Level** | ⏱️ (Minutes per day) |
#     | **Daily Steps**             | 🚶 (Number of steps) |
#     | **Stress Level**            | 😟 (Scale of 1 to 10) |
#
# <br>
#
# 3. **Sleep Health** 💤
#
#     | |  |
#     |-------------------|-------------|
#     | **Sleep Duration**  | ⏰ (Hours per day) |
#     | **Quality of Sleep** | ⭐ (Scale of 1 to 10) |
#     | **Sleep Disorder**   | 🤕 (None, Insomnia, Sleep Apnea) - **Target Variable** |
#
# <br>
#
# 4. **Cardiovascular Health** ❤️
#
#     | |  |
#     |--------------|-------------|
#     | **BMI Category** | 📏 (Underweight, Normal, Overweight, Obese) |
#     | **Blood Pressure** | 🌡️ (Systolic/Diastolic) |
#     | **Heart Rate** | 💓 (Beats per minute) |
#
# <br>
#
# Using this dataset we are going to be answering the following questions:
#
#
#
# 1. Test
# 2. Test
# 3. Test
# 4. Test
#
#
# ### Test

# %% [markdown]
# ## Step 1 - Modules
# As a first step we will import all necessary modules.

# %%
# Import modules

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import plotly.express as px

# %% [markdown]
# ## Step 2 - Data Import + First Look
# Next step we will look at the dataset and get a first overview as to what it looks like.

# %%
df = pd.read_csv("Sleep_health_and_lifestyle_dataset_FINAL.csv")

# %%
df.shape

print ("We have 15 columns and 374 rows.")
# Out:
# We have 15 columns and 374 rows.

# %%
df.head(5)
# Out:
#    Person ID Gender  Gender Count  Employee Count  Age            Occupation  \
# 0          1   Male             1               1   27     Software Engineer
# 1          2   Male             1               1   28                Doctor
# 2          3   Male             1               1   28                Doctor
# 3          4   Male             1               1   28  Sales Representative
# 4          5   Male             1               1   28  Sales Representative
#
#    Sleep Duration in Hours  Quality of Sleep  Physical Activity in Min  \
# 0                      6.1                 6                        42
# 1                      6.2                 6                        60
# 2                      6.2                 6                        60
# 3                      5.9                 4                        30
# 4                      5.9                 4                        30
#
#    Stress Level BMI Category Blood Pressure  Heart Rate  Daily Steps  \
# 0             6   Overweight         126/83          77         4200
# 1             8       Normal         125/80          75        10000
# 2             8       Normal         125/80          75        10000
# 3             8        Obese         140/90          85         3000
# 4             8        Obese         140/90          85         3000
#
#   Sleep Disorder
# 0    No Disorder
# 1    No Disorder
# 2    No Disorder
# 3    Sleep Apnea
# 4    Sleep Apnea

# %%
df.info()

print ("\n\nFINDINGS")
print ("\nUsing 'df.info()' provides a quick overview and grants us insight into the dtypes as well as the null values.")
print ("")
print ("Our dataset looks rather clean as we have no null values to take care of.")
print ("In addition we have 9 int columns, 5 int columns and 1 float column.")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Person ID                 374 non-null    int64
#  1   Gender                    374 non-null    object
#  2   Gender Count              374 non-null    int64
#  3   Employee Count            374 non-null    int64
#  4   Age                       374 non-null    int64
#  5   Occupation                374 non-null    object
#  6   Sleep Duration in Hours   374 non-null    float64
#  7   Quality of Sleep          374 non-null    int64
#  8   Physical Activity in Min  374 non-null    int64
#  9   Stress Level              374 non-null    int64
#  10  BMI Category              374 non-null    object
#  11  Blood Pressure            374 non-null    object
#  12  Heart Rate                374 non-null    int64
#  13  Daily Steps               374 non-null    int64
#  14  Sleep Disorder            374 non-null    object
# dtypes: float64(1), int64(9), object(5)
# memory usage: 44.0+ KB
#
#
# FINDINGS
#
# Using 'df.info()' provides a quick overview and grants us insight into the dtypes as well as the null values.
#
# Our dataset looks rather clean as we have no null values to take care of.
# In addition we have 9 int columns, 5 int columns and 1 float column.

# %%
df.describe().round(2)
# Out:
#        Person ID  Gender Count  Employee Count     Age  \
# count     374.00         374.0           374.0  374.00
# mean      187.50           1.0             1.0   42.18
# std       108.11           0.0             0.0    8.67
# min         1.00           1.0             1.0   27.00
# 25%        94.25           1.0             1.0   35.25
# 50%       187.50           1.0             1.0   43.00
# 75%       280.75           1.0             1.0   50.00
# max       374.00           1.0             1.0   59.00
#
#        Sleep Duration in Hours  Quality of Sleep  Physical Activity in Min  \
# count                   374.00            374.00                    374.00
# mean                      7.13              7.31                     59.17
# std                       0.80              1.20                     20.83
# min                       5.80              4.00                     30.00
# 25%                       6.40              6.00                     45.00
# 50%                       7.20              7.00                     60.00
# 75%                       7.80              8.00                     75.00
# max                       8.50              9.00                     90.00
#
#        Stress Level  Heart Rate  Daily Steps
# count        374.00      374.00       374.00
# mean           5.39       70.17      6816.84
# std            1.77        4.14      1617.92
# min            3.00       65.00      3000.00
# 25%            4.00       68.00      5600.00
# 50%            5.00       70.00      7000.00
# 75%            7.00       72.00      8000.00
# max            8.00       86.00     10000.00

# %%
round (df.describe(exclude = 'object'), 2).style.background_gradient(cmap='BuPu')
# Out:
# <style type="text/css">
# #T_dedd7_row0_col0, #T_dedd7_row0_col1, #T_dedd7_row0_col2, #T_dedd7_row0_col3, #T_dedd7_row0_col4, #T_dedd7_row0_col5, #T_dedd7_row0_col6, #T_dedd7_row0_col7, #T_dedd7_row0_col8, #T_dedd7_row7_col0, #T_dedd7_row7_col9 {
#   background-color: #4d004b;
#   color: #f1f1f1;
# }
# #T_dedd7_row0_col9, #T_dedd7_row1_col1, #T_dedd7_row1_col2, #T_dedd7_row2_col1, #T_dedd7_row2_col2, #T_dedd7_row2_col3, #T_dedd7_row2_col4, #T_dedd7_row2_col5, #T_dedd7_row2_col6, #T_dedd7_row2_col7, #T_dedd7_row2_col8, #T_dedd7_row3_col0, #T_dedd7_row3_col1, #T_dedd7_row3_col2, #T_dedd7_row3_col7, #T_dedd7_row4_col1, #T_dedd7_row4_col2, #T_dedd7_row5_col1, #T_dedd7_row5_col2, #T_dedd7_row6_col1, #T_dedd7_row6_col2, #T_dedd7_row7_col1, #T_dedd7_row7_col2 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_dedd7_row1_col0, #T_dedd7_row5_col0 {
#   background-color: #8c95c6;
#   color: #f1f1f1;
# }
# #T_dedd7_row1_col3 {
#   background-color: #e6f0f7;
#   color: #000000;
# }
# #T_dedd7_row1_col4, #T_dedd7_row1_col5, #T_dedd7_row5_col4, #T_dedd7_row6_col4, #T_dedd7_row6_col5, #T_dedd7_row7_col7 {
#   background-color: #f4fafc;
#   color: #000000;
# }
# #T_dedd7_row1_col6 {
#   background-color: #e4eef5;
#   color: #000000;
# }
# #T_dedd7_row1_col7, #T_dedd7_row5_col7 {
#   background-color: #f6fbfc;
#   color: #000000;
# }
# #T_dedd7_row1_col8, #T_dedd7_row5_col8 {
#   background-color: #d2e2ee;
#   color: #000000;
# }
# #T_dedd7_row1_col9 {
#   background-color: #8b5caa;
#   color: #f1f1f1;
# }
# #T_dedd7_row2_col0 {
#   background-color: #b5cce3;
#   color: #000000;
# }
# #T_dedd7_row2_col9 {
#   background-color: #dfebf4;
#   color: #000000;
# }
# #T_dedd7_row3_col3 {
#   background-color: #eef6fa;
#   color: #000000;
# }
# #T_dedd7_row3_col4, #T_dedd7_row4_col4, #T_dedd7_row4_col5, #T_dedd7_row5_col5, #T_dedd7_row6_col7 {
#   background-color: #f5fafc;
#   color: #000000;
# }
# #T_dedd7_row3_col5, #T_dedd7_row4_col7 {
#   background-color: #f6fbfd;
#   color: #000000;
# }
# #T_dedd7_row3_col6 {
#   background-color: #f3f9fb;
#   color: #000000;
# }
# #T_dedd7_row3_col8 {
#   background-color: #d6e4f0;
#   color: #000000;
# }
# #T_dedd7_row3_col9 {
#   background-color: #bacfe4;
#   color: #000000;
# }
# #T_dedd7_row4_col0 {
#   background-color: #bfd3e6;
#   color: #000000;
# }
# #T_dedd7_row4_col3 {
#   background-color: #eaf3f8;
#   color: #000000;
# }
# #T_dedd7_row4_col6 {
#   background-color: #ebf3f8;
#   color: #000000;
# }
# #T_dedd7_row4_col8 {
#   background-color: #d3e2ef;
#   color: #000000;
# }
# #T_dedd7_row4_col9 {
#   background-color: #8c88bf;
#   color: #f1f1f1;
# }
# #T_dedd7_row5_col3 {
#   background-color: #e6f0f6;
#   color: #000000;
# }
# #T_dedd7_row5_col6, #T_dedd7_row6_col3 {
#   background-color: #e3eef5;
#   color: #000000;
# }
# #T_dedd7_row5_col9 {
#   background-color: #8a55a7;
#   color: #f1f1f1;
# }
# #T_dedd7_row6_col0 {
#   background-color: #88409c;
#   color: #f1f1f1;
# }
# #T_dedd7_row6_col6 {
#   background-color: #d9e6f1;
#   color: #000000;
# }
# #T_dedd7_row6_col8 {
#   background-color: #d1e1ee;
#   color: #000000;
# }
# #T_dedd7_row6_col9 {
#   background-color: #863092;
#   color: #f1f1f1;
# }
# #T_dedd7_row7_col3 {
#   background-color: #ddeaf3;
#   color: #000000;
# }
# #T_dedd7_row7_col4, #T_dedd7_row7_col5 {
#   background-color: #f3f9fc;
#   color: #000000;
# }
# #T_dedd7_row7_col6 {
#   background-color: #cddeec;
#   color: #000000;
# }
# #T_dedd7_row7_col8 {
#   background-color: #c7d9e9;
#   color: #000000;
# }
# </style>
# <table id="T_dedd7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dedd7_level0_col0" class="col_heading level0 col0" >Person ID</th>
#       <th id="T_dedd7_level0_col1" class="col_heading level0 col1" >Gender Count</th>
#       <th id="T_dedd7_level0_col2" class="col_heading level0 col2" >Employee Count</th>
#       <th id="T_dedd7_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_dedd7_level0_col4" class="col_heading level0 col4" >Sleep Duration in Hours</th>
#       <th id="T_dedd7_level0_col5" class="col_heading level0 col5" >Quality of Sleep</th>
#       <th id="T_dedd7_level0_col6" class="col_heading level0 col6" >Physical Activity in Min</th>
#       <th id="T_dedd7_level0_col7" class="col_heading level0 col7" >Stress Level</th>
#       <th id="T_dedd7_level0_col8" class="col_heading level0 col8" >Heart Rate</th>
#       <th id="T_dedd7_level0_col9" class="col_heading level0 col9" >Daily Steps</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dedd7_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_dedd7_row0_col0" class="data row0 col0" >374.000000</td>
#       <td id="T_dedd7_row0_col1" class="data row0 col1" >374.000000</td>
#       <td id="T_dedd7_row0_col2" class="data row0 col2" >374.000000</td>
#       <td id="T_dedd7_row0_col3" class="data row0 col3" >374.000000</td>
#       <td id="T_dedd7_row0_col4" class="data row0 col4" >374.000000</td>
#       <td id="T_dedd7_row0_col5" class="data row0 col5" >374.000000</td>
#       <td id="T_dedd7_row0_col6" class="data row0 col6" >374.000000</td>
#       <td id="T_dedd7_row0_col7" class="data row0 col7" >374.000000</td>
#       <td id="T_dedd7_row0_col8" class="data row0 col8" >374.000000</td>
#       <td id="T_dedd7_row0_col9" class="data row0 col9" >374.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dedd7_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_dedd7_row1_col0" class="data row1 col0" >187.500000</td>
#       <td id="T_dedd7_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_dedd7_row1_col2" class="data row1 col2" >1.000000</td>
#       <td id="T_dedd7_row1_col3" class="data row1 col3" >42.180000</td>
#       <td id="T_dedd7_row1_col4" class="data row1 col4" >7.130000</td>
#       <td id="T_dedd7_row1_col5" class="data row1 col5" >7.310000</td>
#       <td id="T_dedd7_row1_col6" class="data row1 col6" >59.170000</td>
#       <td id="T_dedd7_row1_col7" class="data row1 col7" >5.390000</td>
#       <td id="T_dedd7_row1_col8" class="data row1 col8" >70.170000</td>
#       <td id="T_dedd7_row1_col9" class="data row1 col9" >6816.840000</td>
#     </tr>
#     <tr>
#       <th id="T_dedd7_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_dedd7_row2_col0" class="data row2 col0" >108.110000</td>
#       <td id="T_dedd7_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_dedd7_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_dedd7_row2_col3" class="data row2 col3" >8.670000</td>
#       <td id="T_dedd7_row2_col4" class="data row2 col4" >0.800000</td>
#       <td id="T_dedd7_row2_col5" class="data row2 col5" >1.200000</td>
#       <td id="T_dedd7_row2_col6" class="data row2 col6" >20.830000</td>
#       <td id="T_dedd7_row2_col7" class="data row2 col7" >1.770000</td>
#       <td id="T_dedd7_row2_col8" class="data row2 col8" >4.140000</td>
#       <td id="T_dedd7_row2_col9" class="data row2 col9" >1617.920000</td>
#     </tr>
#     <tr>
#       <th id="T_dedd7_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_dedd7_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_dedd7_row3_col1" class="data row3 col1" >1.000000</td>
#       <td id="T_dedd7_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_dedd7_row3_col3" class="data row3 col3" >27.000000</td>
#       <td id="T_dedd7_row3_col4" class="data row3 col4" >5.800000</td>
#       <td id="T_dedd7_row3_col5" class="data row3 col5" >4.000000</td>
#       <td id="T_dedd7_row3_col6" class="data row3 col6" >30.000000</td>
#       <td id="T_dedd7_row3_col7" class="data row3 col7" >3.000000</td>
#       <td id="T_dedd7_row3_col8" class="data row3 col8" >65.000000</td>
#       <td id="T_dedd7_row3_col9" class="data row3 col9" >3000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dedd7_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_dedd7_row4_col0" class="data row4 col0" >94.250000</td>
#       <td id="T_dedd7_row4_col1" class="data row4 col1" >1.000000</td>
#       <td id="T_dedd7_row4_col2" class="data row4 col2" >1.000000</td>
#       <td id="T_dedd7_row4_col3" class="data row4 col3" >35.250000</td>
#       <td id="T_dedd7_row4_col4" class="data row4 col4" >6.400000</td>
#       <td id="T_de
